# %%
import pandas as pd
import numpy as np
import ast

# %%
save_file = "saved.csv"
small_df = pd.read_csv(save_file)

# %%
small_df['stemmed_tokens'] = pd.Series(small_df['stemmed_tokens'])
small_df['sentiment'] = pd.Series(small_df['sentiment'])

# %%
small_df.stemmed_tokens = small_df.stemmed_tokens.map(lambda x: ast.literal_eval(x))

# %% [markdown]
# # Implementing the Word2Vec Model
#
# In this Notebook, an implementation of the Word2Vec original paper model will be presented,
# to produce a vectorial space using the previously obtained stemmed tokens, as to allow a Random Forest decision tree algorithm
# to classify tweets, based on their lexical content
#
# To see more about an implementation of the Word2Vec model, access the [official tutorial from PyTorch](https://pytorch.org/tutorials/beginner/nlp/word_embeddings_tutorial.html).
# If you'd like to read the original paper, access its [arxiv page](https://arxiv.org/abs/1301.3781).

# %%
from models import word2vec
import time
# Skip-gram model (sg = 1)
size = 400
window = 3
min_count = 1
workers = 3
sg = 1

model_file = 'word2vec.model'
start_time = time.time()
stemmed_tokens = small_df['stemmed_tokens']

w2v_model = Word2Vec(stemmed_tokens, vector_size=size, min_count = min_count, workers = workers, window = window, sg = sg)
print("Time taken to train word2vec model: " + str(time.time() - start_time))
w2v_model.save(model_file)

# %%
w2v_model.wv.key_to_index.keys()

# %%
w2v_model.wv.key_to_index.keys()
# Out:
# dict_keys(['to', 'unit', 'the', 'you', 'flight', 'for', 'on', 'and', 'jetblu', 'my', 'thank', 'southwestair', 'in', 'it', 'is', 'of', 'co', 'http', 'me', 'your', 'have', 'that', 'can', 'with', 'wa', 'at', 'get', 'be', 'thi', 'from', 'not', 'virginamerica', 'we', 'but', 'ar', 'just', 'no', 'so', 'do', 'help', 'servic', 'will', 'time', 'us', 'fly', 'now', 'delai', 'an', 'custom', 'our', 'usairwai', 'americanair', 'out', 'what', 'bag', 'there', 'thei', 'up', 'all', 'airlin', 'plane', 'if', 'would', 'hour', 'great', 'go', 'how', 'amp', 'cancel', 'when', 'pleas', 'need', 'seat', 'check', 'as', 'been', 'wait', 'book', 'gate', 'make', 'about', 'love', 'dai', 'or', 'am', 'ani', 'like', 'why', 'back', 'got', 'gui', 'still', 'ua', 'ha', 'ticket', 'todai', 'know', 'work', 'had', 'new', 'dm', 'chang', 'good', 'see', 'after', 'travel', 're', 'don', 'wai', 'board', 'miss', 'by', 'more', 'take', 'look', 'again', 'much', 'll', 'call', 'airport', 'did', 'late', 'agent', 'crew', 'try', 'last', 've', 'best', 'follow', 'first', 'tomorrow', 'problem', 'realli', 'home', 'onli', 'veri', 'trip', 'want', 'fleet', 'she', 'let', 'over', 'fleek', 'should', 'ye', 'even', 'email', 'connect', 'flightl', 'were', 'next', 'sent', 'hr', 'here', 'then', 'sai', 'awesom', 'never', 'who', 'min', 'issu', 'too', 'hope', 'respons', 'peopl', 'appreci', 'could', 'hi', 'becaus', 'sfo', 'made', 'give', 'week', 'weather', 'number', 'anoth', 'ever', 'phone', 'them', 'off', 'minut', 'he', 'sure', 'passeng', 'other', 'baggag', 'staff', 'right', 'lost', 'amaz', 'experi', 'lax', 'well', 'befor', 'show', 'think', 'left', 'than', 'better', 'land', 'tonight', 'luggag', 'reserv', 'come', 'their', 'through', 'ord', 'year', 'arriv', 'nice', 'her', 'didn', 'two', 'due', 'care', 'upgrad', 'morn', 'keep', 'doe', 'worst', 'final', 'some', 'into', 'sit', 'attend', 'tell', 'told', 'ewr', 'ask', 'confirm', 'pilot', 'free', 'start', 'find', 'long', 'class', 'thx', 'rt', 'team', 'where', 'alreadi', 'someon', 'leav', 'jfk', 'hold', 'updat', 'night', 'alwai', 'la', 'busi', 'mile', 'done', 'websit', 'pai', 'offer', 'send', 'name', 'thing', 'refund', 'st', 'also', 'down', 'bad', 'rebook', 'pass', 'tweet', 'same', 'chanc', 'vega', 'denver', 'charg', 'happen', 'yet', 'southwest', 'open', 'wifi', 'via', 'job', 'ok', 'repli', 'air', 'deal', 'said', 'pm', 'point', 'line', 'chicago', 'flt', 'claim', 'disappoint', 'avail', 'statu', 'newark', 'employe', 'info', 'doesn', 'anyth', 'san', 'earli', 'put', 'th', 'abl', 'fix', 'voucher', 'iad', 'ago', 'person', 'direct', 'app', 'houston', 'actual', 'friend', 'return', 'mani', 'though', 'sinc', 'happi', 'wonder', 'mean', 'stuck', 'receiv', 'bo', 'snow', 'fee', 'add', 'tri', 'lot', 'mai', 'flightr', 'imaginedragon', 'hotel', 'hear', 'site', 'everi', 'kid', 'contact', 'question', 'won', 'cool', 'gt', 'option', 'terribl', 'rock', 'month', 'stop', 'oh', 'understand', 'fail', 'earlier', 'awai', 'current', 'ceo', 'seem', 'onlin', 'someth', 'possibl', 'differ', 'reason', 'move', 'credit', 'those', 'big', 'request', 'suck', 'boston', 'soon', 'quick', 'messag', 'famili', 'instead', 'schedul', 'delta', 'unitedairlin', 'noth', 'which', 'intern', 'frustrat', 'carri', 'twitter', 'rep', 'iah', 'found', 'departur', 'system', 'might', 'link', 'rout', 'provid', 'assist', 'dalla', 'yesterdai', 'card', 'took', 'plu', 'ground', 'lol', 'while', 'depart', 'share', 'forward', 'plan', 'respond', 'everyon', 'fare', 'dc', 'expect', 'far', 'compani', 'mayb', 'den', 'sorri', 'head', 'member', 'destin', 'termin', 'polici', 'everyth', 'extra', 'few', 'answer', 'old', 'talk', 'aa', 'broken', 'vacat', 'hei', 'isn', 'onc', 'most', 'wasn', 'nyc', 'tarmac', 'him', 'without', 'least', 'caus', 'until', 'group', 'both', 'bring', 'desk', 'haven', 'row', 'price', 'dure', 'club', 'phl', 'life', 'end', 'airwai', 'second', 'ad', 'speak', 'yr', 'watch', 'worri', 'account', 'littl', 'less', 'world', 'serious', 'went', 'atlanta', 'car', 'paid', 'austin', 'date', 'room', 'own', 'flightlat', 'pl', 'full', 'w ...

# %%
import pandas as pd
import numpy as np
import ast

# %%
save_file = "saved.csv"
small_df = pd.read_csv(save_file)

# %%
small_df['stemmed_tokens'] = pd.Series(small_df['stemmed_tokens'])
small_df['sentiment'] = pd.Series(small_df['sentiment'])

# %%
small_df.stemmed_tokens = small_df.stemmed_tokens.map(lambda x: ast.literal_eval(x))

# %% [markdown]
# # Implementing the Word2Vec Model
#
# In this Notebook, an implementation of the Word2Vec original paper model will be presented,
# to produce a vectorial space using the previously obtained stemmed tokens, as to allow a Random Forest decision tree algorithm
# to classify tweets, based on their lexical content
#
# To see more about an implementation of the Word2Vec model, access the [official tutorial from PyTorch](https://pytorch.org/tutorials/beginner/nlp/word_embeddings_tutorial.html).
# If you'd like to read the original paper, access its [arxiv page](https://arxiv.org/abs/1301.3781).

# %%
import importlib
import src.models as models
import time

# %%
importlib.reload(models)
# Out:
# <module 'src.models' from 'C:\\Users\\rzimm\\Workspace\\data\\word2vec_sa\\src\\models.py'>

# %%
example = small_df.stemmed_tokens
models.CBOW_transform(example, 2)
# Out:
# [([['virginamerica',
#     'plu',
#     'you',
#     've',
#     'ad',
#     'commerci',
#     'to',
#     'the',
#     'experi',
#     'tacki'],
#    ['virginamerica',
#     'ye',
#     'nearli',
#     'everi',
#     'time',
#     'fli',
#     'vx',
#     'thi',
#     'ear',
#     'worm',
#     'won',
#     'go',
#     'away'],
#    ['virginamerica',
#     'it',
#     'wa',
#     'amaz',
#     'and',
#     'arriv',
#     'an',
#     'hour',
#     'earli',
#     'you',
#     're',
#     'too',
#     'good',
#     'to',
#     'me']],
#   ['virginamerica', 'well', 'didn', 'but', 'now', 'do']),
#  ([['virginamerica',
#     'ye',
#     'nearli',
#     'everi',
#     'time',
#     'fli',
#     'vx',
#     'thi',
#     'ear',
#     'worm',
#     'won',
#     'go',
#     'away'],
#    ['virginamerica', 'well', 'didn', 'but', 'now', 'do'],
#    ['virginamerica',
#     'lt',
#     'pretti',
#     'graphic',
#     'so',
#     'much',
#     'better',
#     'than',
#     'minim',
#     'iconographi']],
#   ['virginamerica',
#    'it',
#    'wa',
#    'amaz',
#    'and',
#    'arriv',
#    'an',
#    'hour',
#    'earli',
#    'you',
#    're',
#    'too',
#    'good',
#    'to',
#    'me']),
#  ([['virginamerica', 'well', 'didn', 'but', 'now', 'do'],
#    ['virginamerica',
#     'it',
#     'wa',
#     'amaz',
#     'and',
#     'arriv',
#     'an',
#     'hour',
#     'earli',
#     'you',
#     're',
#     'too',
#     'good',
#     'to',
#     'me'],
#    ['virginamerica',
#     'thi',
#     'is',
#     'such',
#     'great',
#     'deal',
#     'alreadi',
#     'think',
#     'about',
#     'my',
#     'nd',
#     'trip',
#     'to',
#     'australia',
#     'amp',
#     'haven',
#     'even',
#     'gone',
#     'on',
#     'my',
#     'st',
#     'trip',
#     'yet']],
#   ['virginamerica',
#    'lt',
#    'pretti',
#    'graphic',
#    'so',
#    'much',
#    'better',
#    'than',
#    'minim',
#    'iconographi']),
#  ([['virginamerica',
#     'it',
#     'wa',
#     'amaz',
#     'and',
#     'arriv',
#     'an',
#     'hour',
#     'earli',
#     'you',
#     're',
#     'too',
#     'good',
#     'to',
#     'me'],
#    ['virginamerica',
#     'lt',
#     'pretti',
#     'graphic',
#     'so',
#     'much',
#     'better',
#     'than',
#     'minim',
#     'iconographi'],
#    ['virginamerica',
#     'virginmedia',
#     'fli',
#     'your',
#     'fabul',
#     'seduct',
#     'sky',
#     'again',
#     'take',
#     'all',
#     'the',
#     'stress',
#     'away',
#     'from',
#     'travel',
#     'http',
#     'co',
#     'ahlxhhkiyn']],
#   ['virginamerica',
#    'thi',
#    'is',
#    'such',
#    'great',
#    'deal',
#    'alreadi',
#    'think',
#    'about',
#    'my',
#    'nd',
#    'trip',
#    'to',
#    'australia',
#    'amp',
#    'haven',
#    'even',
#    'gone',
#    'on',
#    'my',
#    'st',
#    'trip',
#    'yet']),
#  ([['virginamerica',
#     'lt',
#     'pretti',
#     'graphic',
#     'so',
#     'much',
#     'better',
#     'than',
#     'minim',
#     'iconographi'],
#    ['virginamerica',
#     'thi',
#     'is',
#     'such',
#     'great',
#     'deal',
#     'alreadi',
#     'think',
#     'about',
#     'my',
#     'nd',
#     'trip',
#     'to',
#     'australia',
#     'amp',
#     'haven',
#     'even',
#     'gone',
#     'on',
#     'my',
#     'st',
#     'trip',
#     'yet'],
#    ['virginamerica', 'thank']],
#   ['virginamerica',
#    'virginmedia',
#    'fli',
#    'your',
#    'fabul',
#    'seduct',
#    'sky',
#    'again',
#    'take',
#    'all',
#    'the',
#    'stress',
#    'away',
#    'from',
#    'travel',
#    'http',
#    'co',
#    'ahlxhhkiyn']),
#  ([['virginamerica',
#     'thi',
#     'is',
#     'such',
#     'great',
#     'deal',
#     'alreadi',
#     'think',
#     'about',
#     'my',
#     'nd',
#     'trip',
#     'to',
#     'australia',
#     'amp',
#     'haven',
#     'even',
#     'gone',
#     'on',
#     'my',
#     'st',
#     'trip',
#     'yet'],
#    ['virginamerica',
#     'virginmedia',
#     'fli',
#     'your',
#     'fabul',
#     'seduct',
#     'sky',
#     'again',
#     'take',
#     'all',
#     'the',
#     'stress',
#     'away',
#     'from',
#     'travel',
#     'http',
#     'co',
#     'ahlxhhkiyn'],
#    ['virginamerica',
#     'so',
#     'excit',
#     'for',
#     'my',
#     'first',
#     'cross',
#     'countri',
#     'flight',
#     'lax',
#     'to',
#     'mco',
#     've',
#     'heard',
#     'noth',
#     'but',
#     'great',
#     'thing',
#     'about',
#     'virgin',
#     'america',
#     'daystogo']],
#   ['virginamerica', 'thank']),
#  ([['virginamerica',
#     'virginmedia',
#     'fli',
#     'your',
#     'fabul',
#     'seduct',
#     'sky',
#     'again',
#     'take',
#     'all',
#     'the',
#     'stress',
#     'away',
#     'from',
#     'travel',
#     'http',
#     'co',
#     'ahlxhhkiyn'],
#    ['virginamerica', 'thank'],
#    ['fli', 'virginamerica']],
#   ['virginamerica',
#    'so',
#    'excit',
#    'for',
#    'my',
#    'first',
#    'cross',
#    'countri',
#    'flight',
#    'lax',
#    'to',
#    'mco',
#    've',
#    'heard',
#    'noth',
#    'but',
#    'great',
#    'thing',
#    'about',
#    'virgin',
#    'america',
#    'daystogo']),
#  ([['virginamerica', 'thank'],
#    ['virginamerica',
#     'so',
#     'excit',
#     'for',
#     'my',
#     'first',
#     'cross',
#     'countri',
#     'flight',
#     'lax',
#     'to',
#     'mco',
#     've',
#     'heard',
#     'noth',
#     'but',
#     'great',
#     'thing',
#     'about',
#     'virgin',
#     'america',
#     'daystogo'],
#    ['virginamerica',
#     'you',
#     'know',
#     'what',
#     'would',
#     'be',
#     'amazingli',
#     'awesom',
#     'bo',
#     'fll',
#     'pleas',
#     'want',
#     'to',
#     'fli',
#     'with',
#     'onli',
#     'you']],
#   ['fli', 'virginamerica']),
#  ([['virginamerica',
#     'so',
#     'excit',
#     'for',
#     'my',
#     'first',
#     'cross',
#     'countri',
#     'flight',
#     'lax',
#     'to',
#     'mco',
#     've',
#     'heard',
#     'noth',
#     'but',
#     'great',
#     'thing',
#     'about',
#     'virgin',
#     'america',
#     'daystogo'],
#    ['fli', 'virginamerica'],
#    ['virginamerica', 'love', 'thi', 'graphic', 'http', 'co', 'ut', 'grrwaaa']],
#   ['virginamerica',
#    'you',
#    'know',
#    'what',
#    'would',
#    'be',
#    'amazingli',
#    'awesom',
#    'bo',
#    'fll',
#    'pleas',
#    'want',
#    'to',
#    'fli',
#    'with',
#    'onli',
#    'you']),
#  ([['fli', 'virginamerica'],
#    ['virginamerica',
#     'you',
#     'know',
#     'what',
#     'would',
#     'be',
#     'amazingli',
#     'awesom',
#     'bo',
#     'fll',
#     'pleas',
#     'want',
#     'to',
#     'fli',
#     'with',
#     'onli',
#     'you'],
#    ['virginamerica',
#     'love',
#     'the',
#     'hipster',
#     'innov',
#     'you',
#     'are',
#     'feel',
#     'good',
#     'brand']],
#   ['virginamerica', 'love', 'thi', 'graphic', 'http', 'co', 'ut', 'grrwaaa']),
#  ([['virginamerica',
#     'you',
#     'know',
#     'what',
#     'would',
#     'be',
#     'amazingli',
#     'awesom',
#     'bo',
#     'fll',
#     'pleas',
#     'want',
#     'to',
#     'fli',
#     'with',
#     'onli',
#     'you'],
#    ['virginamerica', 'love', 'thi', 'graphic', 'http', 'co', 'ut', 'grrwaaa'],
#    ['virginamerica',
#     'thi',
#     'is',
#     'great',
#     'news',
#     'america',
#     'could',
#     'start',
#     'flight',
#     'to',
#     'hawaii',
#     'by',
#     'end',
#     'of',
#     'year',
#     'http',
#     'co',
#     'zy',
#     'fe',
#     'via',
#     'pacificbiznew']],
#   ['virginamerica',
#    'love',
#    'the',
#    'hipster',
#    'innov',
#    'you',
#    'are',
#    'feel',
#    'good',
#    'brand']),
#  ([['virginamerica', 'love', 'thi', 'graphic', 'http', 'co', 'ut', 'grrwaaa'],
#    ['virginamerica',
#     'love',
#     'the',
#     'hipster',
#     'innov',
#     'you',
#     'are',
#     'feel',
#     'good',
#     'brand'],
#    ['virginamerica',
#     'moodlight',
#     'is',
#     'the',
#     'onli',
#     'way',
#     'to',
#     'fli',
#     'best',
#     'experi',
#     'ever',
#     'cool',
#     'and',
#     'calm',
#     'moodlitmonday']],
#   ['virginamerica',
#    'thi',
#    'is',
#    'great',
#    'news',
#    'america',
#    'could',
#    'start',
#    'flight',
#    'to',
#    'hawaii',
#    'by',
#    'end',
#    'of',
#    'year',
#    'http',
#    'co',
#    'zy',
#    'fe',
#    'via',
#    'pacificbiznew']),
#  ([['virginamerica',
#     'love',
#     'the',
#     'hipster',
#     'innov',
#     'you',
#     'are',
#     'feel',
#     'good',
#     'brand'],
#    ['virginamerica',
#     'thi',
#     'is',
#     'great',
#     'news',
#     'america',
#     'could',
#     'start',
#     'flight',
#     'to',
#     'hawaii',
#     'by',
#     'end',
#     'of',
#     'year',
#     'http',
#     'co',
#     'zy',
#     'fe',
#     'via',
#     'pacificbiznew'],
#    ['virginamerica',
#     'freddieaward',
#     'done',
#     'and',
#     'done',
#     'best',
#     'airlin',
#     'around',
#     'hand',
#     'down']],
#   ['virginamerica',
#    'moodlight',
#    'is',
#    'the',
#    'onli',
#    'way',
#    'to',
#    'fli',
#    'best',
#    'experi',
#    'ever',
#    'cool',
#    'and',
#    'calm',
#    'moodlitmonday']),
#  ([['virginamerica',
#     'thi',
#     'is',
#     'great',
#     'news',
#     'america',
#     'could',
#     'start',
#     'flight',
#     'to',
#     'hawaii',
#     'by',
#     'end',
#     'of',
#     'year',
#     'http',
#     'co',
#     'zy',
#     'fe',
#     'via',
#     'pacificbiznew'],
#    ['virginamerica',
#     'moodlight',
#     'is',
#     'the',
#     'onli',
#     'way',
#     'to',
#     'fli',
#     'best',
#     'experi',
#     'ever',
#     'cool',
#     'and',
#     'calm',
#     'moodlitmonday'],
#    ['virginamerica',
#     'view',
#     'of',
#     'downtown',
#     'lo',
#     'angel',
#     'the',
#     'hollywood',
#     'sign',
#     'and',
#     'beyond',
#     'that',
#     'rain',
#     'in',
#     'the',
#     'mountain',
#     'http',
#     'co',
#     'dw',
#     'nf',
#     'ibtr']],
#   ['virginamerica',
#    'freddieaward',
#    'done',
#    'and',
#    'done',
#    'best',
#    'airlin',
#    'around',
#    'hand',
#    'down']),
#  ([['virginamerica',
#     'moodlight',
#     'is',
#     'the',
#     'onli',
#     'way',
#     'to',
#     'fli',
#     'best',
#     'experi',
#     'ever',
#     'cool',
#     'and',
#     'calm',
#     'moodlitmonday'],
#    ['virginamerica',
#     'freddieaward',
#     'done',
#     'and',
#     'done',
#     'best',
#     'airlin',
#     'around',
#     'hand',
#     'down'],
#    ['virginamerica', 'elevategold', 'for', 'good', 'reason', 'you', 'rock']],
#   ['virginamerica',
#    'view',
#    'of',
#    'downtown',
#    'lo',
#    'angel',
#    'the',
#    'hollywood',
#    'sign',
#    'and',
#    'beyond',
#    'that',
#    'rain',
#    'in',
#    'the',
#    'mountain',
#    'http',
#    'co',
#    'dw',
#    'nf',
#    'ibtr']),
#  ([['virginamerica',
#     'freddieaward',
#     'done',
#     'and',
#     'done',
#     'best',
#     'airlin',
#     'around',
#     'hand',
#     'down'],
#    ['virginamerica',
#     'view',
#     'of',
#     'downtown',
#     'lo',
#     'angel',
#     'the',
#     'hollywood',
#     'sign',
#     'and',
#     'beyond',
#     'that',
#     'rain',
#     'in',
#     'the',
#     'mountain',
#     'http',
#     'co',
#     'dw',
#     'nf',
#     'ibtr'],
#    ['virginamerica', 'wow', 'thi', 'just', 'blew', 'my', 'mind']],
#   ['virginamerica', 'elevategold', 'for', 'good', 'reason', 'you', 'rock']),
#  ([['virginamerica',
#     'view',
#     'of',
#     'downtown',
#     'lo',
#     'angel',
#     'the',
#     'hollywood',
#     'sign',
#     'and',
#     'beyond',
#     'that',
#     'rain',
#     'in',
#     'the',
#     'mountain',
#     'http',
#     'co',
#     'dw',
#     'nf',
#     'ibtr'],
#    ['virginamerica', 'elevategold', 'for', 'good', 'reason', 'you', 'rock'],
#    ['virginamerica',
#     'ladygaga',
#     'carrieunderwood',
#     'juli',
#     'andrew',
#     'all',
#     'the',
#     'way',
#     'though',
#     'ladygaga',
#     'wa',
#     'veri',
#     'impress',
#     'no',
#     'to',
#     'carrieunderwood']],
#   ['virginamerica', 'wow', 'thi', 'just', 'blew', 'my', 'mind']),
#  ([['virginamerica', 'elevategold', 'for', 'good', 'reason', 'you', 'rock'],
#    ['virginamerica', 'wow', 'thi', 'just', 'blew', 'my', 'mind'],
#    ['virginamerica',
#     'you',
#     'know',
#     'it',
#     'need',
#     'it',
#     'on',
#     'my',
#     'spotifi',
#     'stat',
#     'guiltypleasur']],
#   ['virginamerica',
#    'ladygaga',
#    'carrieunderwood',
#    'juli',
#    'andrew',
#    'all',
#    'the',
#    'way',
#    'though',
#    'ladygaga',
#    'wa',
#    'veri',
#    'impress',
#    'no',
#    'to',
#    'carrieunderwood']),
#  ([['virginamerica', 'wow', 'thi', 'just', 'blew', 'my', 'mind'],
#    ['virginamerica',
#     'ladygaga',
#     'carrieunderwood',
#     'juli',
#     'andrew',
#     'all',
#     'the',
#     'way',
#     'though',
#     'ladygaga',
#     'wa',
#     'veri',
#     'impress',
#     'no',
#     'to',
#     'carrieunderwood'],
#    ['virginamerica',
#     'ladygaga',
#     'carrieunderwood',
#     'ladi',
#     'gaga',
#     'she',
#     'is',
#     'amaz']],
#   ['virginamerica',
#    'you',
#    'know',
#    'it',
#    'need',
#    'it',
#    'on',
#    'my',
#    'spotifi',
#    'stat',
#    'guiltypleasur']),
#  ([['virginamerica',
#     'ladygaga',
#     'carrieunderwood',
#     'juli',
#     'andrew',
#     'all',
#     'the',
#     'way',
#     'though',
#     'ladygaga',
#     'wa',
#     'veri',
#     'impress',
#     'no',
#     'to',
#     'carrieunderwood'],
#    ['virginamerica',
#     'you',
#     'know',
#     'it',
#     'need',
#     'it',
#     'on',
#     'my',
#     'spotifi',
#     'stat',
#     'guiltypleasur'],
#    ['virginamerica',
#     'ladygaga',
#     'carrieunderwood',
#     'love',
#     'all',
#     'three',
#     'but',
#     'you',
#     'realli',
#     'can',
#     'beat',
#     'the',
#     'classic']],
#   ['virginamerica',
#    'ladygaga',
#    'carrieunderwood',
#    'ladi',
#    'gaga',
#    'she',
#    'is',
#    'amaz']),
#  ([['virginamerica',
#     'you',
#     'know',
#     'it',
#     'need',
#     'it',
#     'on',
#     'my',
#     'spotifi',
#     'stat',
#     'guiltypleasur'],
#    ['virginamerica',
#     'ladygaga',
#     'carrieunderwood',
#     'ladi',
#     'gaga',
#     'she',
#     'is',
#     'amaz'],
#    ['virginamerica',
#     'congrat',
#     'on',
#     'win',
#     'the',
#     'travelzoo',
#     'award',
#     'for',
#     'best',
#     'deal',
#     'from',
#     'an',
#     'airlin',
#     'us',
#     'http',
#     'co',
#     'kj',
#     'iljaebv']],
#   ['virginamerica',
#    'ladygaga',
#    'carrieunderwood',
#    'love',
#    'all',
#    'three',
#    'but',
#    'you',
#    'realli',
#    'can',
#    'beat',
#    'the',
#    'classic']),
#  ([['virginamerica',
#     'ladygaga',
#     'carrieunderwood',
#     'ladi',
#     'gaga',
#     'she',
#     'is',
#     'amaz'],
#    ['virginamerica',
#     'ladygaga',
#     'carrieunderwood',
#     'love',
#     'all',
#     'three',
#     'but',
#     'you',
#     'realli',
#     'can',
#     'beat',
#     'the',
#     'classic'],
#    ['virginamerica',
#     'not',
#     'worri',
#     'it',
#     'been',
#     'great',
#     'ride',
#     'in',
#     'new',
#     'plane',
#     'with',
#     'great',
#     'crew',
#     'all',
#     'airlin',
#     'should',
#     'be',
#     'like',
#     'thi']],
#   ['virginamerica',
#    'congrat',
#    'on',
#    'win',
#    'the',
#    'travelzoo',
#    'award',
#    'for',
#    'best',
#    'deal',
#    'from',
#    'an',
#    'airlin',
#    'us',
#    'http',
#    'co',
#    'kj',
#    'iljaebv']),
#  ([['virginamerica',
#     'ladygaga',
#     'carrieunderwood',
#     'love',
#     'all',
#     'three',
#     'but',
#     'you',
#     'realli',
#     'can',
#     'beat',
#     'the',
#     'classic'],
#    ['virginamerica',
#     'congrat',
#     'on',
#     'win',
#     'the',
#     'travelzoo',
#     'award',
#     'for',
#     'best',
#     'deal',
#     'from',
#     'an',
#     'airlin',
#     'us',
#     'http',
#     'co',
#     'kj',
#     'iljaebv'],
#    ['virginamerica',
#     'awesom',
#     'flew',
#     'yall',
#     'sat',
#     'morn',
#     'ani',
#     'way',
#     'we',
#     'can',
#     'correct',
#     'my',
#     'bill']],
#   ['virginamerica',
#    'not',
#    'worri',
#    'it',
#    'been',
#    'great',
#    'ride',
#    'in',
#    'new',
#    'plane',
#    'with',
#    'great',
#    'crew',
#    'all',
#    'airlin',
#    'should',
#    'be',
#    'like',
#    'thi']),
#  ([['virginamerica',
#     'congrat',
#     'on',
#     'win',
#     'the',
#     'travelzoo',
#     'award',
#     'for',
#     'best',
#     'deal',
#     'from',
#     'an',
#     'airlin',
#     'us',
#     'http',
#     'co',
#     'kj',
#     'iljaebv'],
#    ['virginamerica',
#     'not',
#     'worri',
#     'it',
#     'been',
#     'great',
#     'ride',
#     'in',
#     'new',
#     'plane',
#     'with',
#     'great',
#     'crew',
#     'all',
#     'airlin',
#     'should',
#     'be',
#     'like',
#     'thi'],
#    ['virginamerica',
#     've',
#     'appli',
#     'more',
#     'then',
#     'onc',
#     'to',
#     'be',
#     'member',
#     'of',
#     'the',
#     'inflight',
#     'crew',
#     'team',
#     'im',
#     'interest',
#     'flightattend',
#     'dreampath']],
#   ['virginamerica',
#    'awesom',
#    'flew',
#    'yall',
#    'sat',
#    'morn',
#    'ani',
#    'way',
#    'we',
#    'can',
#    'correct',
#    'my',
#    'bill']),
#  ([['virginamerica',
#     'not',
#     'worri',
#     'it',
#     'been',
#     'great',
#     'ride',
#     'in',
#     'new',
#     'plane',
#     'with',
#     'great',
#     'crew',
#     'all',
#     'airlin',
#     'should',
#     'be',
#     'like',
#     'thi'],
#    ['virginamerica',
#     'awesom',
#     'flew',
#     'yall',
#     'sat',
#     'morn',
#     'ani',
#     'way',
#     'we',
#     'can',
#     'correct',
#     'my',
#     'bill'],
#    ['virginamerica',
#     'amaz',
#     'custom',
#     'servic',
#     'again',
#     'raeann',
#     'in',
#     'sf',
#     'she',
#     'the',
#     'best',
#     'customerservic',
#     'virginamerica',
#     'fli']],
#   ['virginamerica',
#    've',
#    'appli',
#    'more',
#    'then',
#    'onc',
#    'to',
#    'be',
#    'member',
#    'of',
#    'the',
#    'inflight',
#    'crew',
#    'team',
#    'im',
#    'interest',
#    'flightattend',
#    'dreampath']),
#  ([['virginamerica',
#     'awesom',
#     'flew',
#     'yall',
#     'sat',
#     'morn',
#     'ani',
#     'way',
#     'we',
#     'can',
#     'correct',
#     'my',
#     'bill'],
#    ['virginamerica',
#     've',
#     'appli',
#     'more',
#     'then',
#     'onc',
#     'to',
#     'be',
#     'member',
#     'of',
#     'the',
#     'inflight',
#     'crew',
#     'team',
#     'im',
#     'interest',
#     'flightattend',
#     'dreampath'],
#    ['virginamerica',
#     'ha',
#     'getaway',
#     'deal',
#     'through',
#     'may',
#     'from',
#     'one',
#     'way',
#     'lot',
#     'of',
#     'cool',
#     'citi',
#     'http',
#     'co',
#     'tzzjhuibch',
#     'cheapflight',
#     'farecompar']],
#   ['virginamerica',
#    'amaz',
#    'custom',
#    'servic',
#    'again',
#    'raeann',
#    'in',
#    'sf',
#    'she',
#    'the',
#    'best',
#    'customerservic',
#    'virginamerica',
#    'fli']),
#  ([['virginamerica',
#     've',
#     'appli',
#     'more',
#     'then',
#     'onc',
#     'to',
#     'be',
#     'member',
#     'of',
#     'the',
#     'inflight',
#     'crew',
#     'team',
#     'im',
#     'interest',
#     'flightattend',
#     'dreampath'],
#    ['virginamerica',
#     'amaz',
#     'custom',
#     'servic',
#     'again',
#     'raeann',
#     'in',
#     'sf',
#     'she',
#     'the',
#     'best',
#     'customerservic',
#     'virginamerica',
#     'fli'],
#    ['virginamerica',
#     'ha',
#     'getaway',
#     'deal',
#     'through',
#     'may',
#     'from',
#     'one',
#     'way',
#     'lot',
#     'of',
#     'cool',
#     'citi',
#     'http',
#     'co',
#     'xi',
#     'yg',
#     'cheapflight',
#     'farecompar']],
#   ['virginamerica',
#    'ha',
#    'getaway',
#    'deal',
#    'through',
#    'may',
#    'from',
#    'one',
#    'way',
#    'lot',
#    'of',
#    'cool',
#    'citi',
#    'http',
#    'co',
#    'tzzjhuibch',
#    'cheapflight',
#    'farecompar']),
#  ([['virginamerica',
#     'amaz',
#     'custom',
#     'servic',
#     'again',
#     'raeann',
#     'in',
#     'sf',
#     'she',
#     'the',
#     'best',
#     'customerservic',
#     'virginamerica',
#     'fli'],
#    ['virginamerica',
#     'ha',
#     'getaway',
#     'deal',
#     'through',
#     'may',
#     'from',
#     'one',
#     'way',
#     'lot',
#     'of',
#     'cool',
#     'citi',
#     'http',
#     'co',
#     'tzzjhuibch',
#     'cheapflight',
#     'farecompar'],
#    ['virginamerica', 'have', 'great', 'week']],
#   ['virginamerica',
#    'ha',
#    'getaway',
#    'deal',
#    'through',
#    'may',
#    'from',
#    'one',
#    'way',
#    'lot',
#    'of',
#    'cool',
#    'citi',
#    'http',
#    'co',
#    'xi',
#    'yg',
#    'cheapflight',
#    'farecompar']),
#  ([['virginamerica',
#     'ha',
#     'getaway',
#     'deal',
#     'through',
#     'may',
#     'from',
#     'one',
#     'way',
#     'lot',
#     'of',
#     'cool',
#     'citi',
#     'http',
#     'co',
#     'tzzjhuibch',
#     'cheapflight',
#     'farecompar'],
#    ['virginamerica',
#     'ha',
#     'getaway',
#     'deal',
#     'through',
#     'may',
#     'from',
#     'one',
#     'way',
#     'lot',
#     'of',
#     'cool',
#     'citi',
#     'http',
#     'co',
#     'xi',
#     'yg',
#     'cheapflight',
#     'farecompar'],
#    ['virginamerica',
#     'come',
#     'back',
#     'to',
#     'phl',
#     'alreadi',
#     'we',
#     'need',
#     'you',
#     'to',
#     'take',
#     'us',
#     'out',
#     'of',
#     'thi',
#     'horribl',
#     'cold',
#     'pleasecomeback',
#     'http',
#     'co',
#     'glxfwp',
#     'nqh']],
#   ['virginamerica', 'have', 'great', 'week']),
#  ([['virginamerica',
#     'ha',
#     'getaway',
#     'deal',
#     'through',
#     'may',
#     'from',
#     'one',
#     'way',
#     'lot',
#     'of',
#     'cool',
#     'citi',
#     'http',
#     'co',
#     'xi',
#     'yg',
#     'cheapflight',
#     'farecompar'],
#    ['virginamerica', 'have', 'great', 'week'],
#    ['virginamerica',
#     'is',
#     'the',
#     'best',
#     'airlin',
#     'have',
#     'flown',
#     'on',
#     'easi',
#     'to',
#     'chang',
#     'your',
#     'reserv',
#     'help',
#     'repres',
#     'amp',
#     'comfort',
#     'fli',
#     'experi']],
#   ['virginamerica',
#    'come',
#    'back',
#    'to',
#    'phl',
#    'alreadi',
#    'we',
#    'need',
#    'you',
#    'to',
#    'take',
#    'us',
#    'out',
#    'of',
#    'thi',
#    'horribl',
#    'cold',
#    'pleasecomeback',
#    'http',
#    'co',
#    'glxfwp',
#    'nqh']),
#  ([['virginamerica', 'have', 'great', 'week'],
#    ['virginamerica',
#     'come',
#     'back',
#     'to',
#     'phl',
#     'alreadi',
#     'we',
#     'need',
#     'you',
#     'to',
#     'take',
#     'us',
#     'out',
#     'of',
#     'thi',
#     'horribl',
#     'cold',
#     'pleasecomeback',
#     'http',
#     'co',
#     'glxfwp',
#     'nqh'],
#    ['virginamerica',
#     'and',
#     'again',
#     'anoth',
#     'rep',
#     'kick',
#     'butt',
#     'naelah',
#     'repres',
#     'your',
#     'team',
#     'so',
#     'beauti',
#     'thank',
#     'you']],
#   ['virginamerica',
#    'is',
#    'the',
#    'best',
#    'airlin',
#    'have',
#    'flown',
#    'on',
#    'easi',
#    'to',
#    'chang',
#    'your',
#    'reserv',
#    'help',
#    'repres',
#    'amp',
#    'comfort',
#    'fli',
#    'experi']),
#  ([['virginamerica',
#     'come',
#     'back',
#     'to',
#     'phl',
#     'alreadi',
#     'we',
#     'need',
#     'you',
#     'to',
#     'take',
#     'us',
#     'out',
#     'of',
#     'thi',
#     'horribl',
#     'cold',
#     'pleasecomeback',
#     'http',
#     'co',
#     'glxfwp',
#     'nqh'],
#    ['virginamerica',
#     'is',
#     'the',
#     'best',
#     'airlin',
#     'have',
#     'flown',
#     'on',
#     'easi',
#     'to',
#     'chang',
#     'your',
#     'reserv',
#     'help',
#     'repres',
#     'amp',
#     'comfort',
#     'fli',
#     'experi'],
#    ['virginamerica',
#     'your',
#     'beauti',
#     'front',
#     'end',
#     'design',
#     'is',
#     'down',
#     'right',
#     'now',
#     'but',
#     'it',
#     'wa',
#     'cool',
#     'to',
#     'still',
#     'book',
#     'my',
#     'ticket',
#     'all',
#     'your',
#     'back',
#     'end',
#     'wa',
#     'secur']],
#   ['virginamerica',
#    'and',
#    'again',
#    'anoth',
#    'rep',
#    'kick',
#    'butt',
#    'naelah',
#    'repres',
#    'your',
#    'team',
#    'so',
#    'beauti',
#    'thank',
#    'you']),
#  ([['virginamerica',
#     'is',
#     'the',
#     'best',
#     'airlin',
#     'have',
#     'flown',
#     'on',
#     'easi',
#     'to',
#     'chang',
#     'your',
#     'reserv',
#     'help',
#     'repres',
#     'amp',
#     'comfort',
#     'fli',
#     'experi'],
#    ['virginamerica',
#     'and',
#     'again',
#     'anoth',
#     'rep',
#     'kick',
#     'butt',
#     'naelah',
#     'repres',
#     'your',
#     'team',
#     'so',
#     'beauti',
#     'thank',
#     'you'],
#    ['virginamerica',
#     'love',
#     'the',
#     'team',
#     'run',
#     'gate',
#     'at',
#     'la',
#     'tonight',
#     'wait',
#     'for',
#     'delay',
#     'flight',
#     'and',
#     'they',
#     'kept',
#     'thing',
#     'entertain']],
#   ['virginamerica',
#    'your',
#    'beauti',
#    'front',
#    'end',
#    'design',
#    'is',
#    'down',
#    'right',
#    'now',
#    'but',
#    'it',
#    'wa',
#    'cool',
#    'to',
#    'still',
#    'book',
#    'my',
#    'ticket',
#    'all',
#    'your',
#    'back',
#    'end',
#    'wa',
#    'secur']),
#  ([['virginamerica',
#     'and',
#     'again',
#     'anoth',
#     'rep',
#     'kick',
#     'butt',
#     'naelah',
#     'repres',
#     'your',
#     'team',
#     'so',
#     'beauti',
#     'thank',
#     'you'],
#    ['virginamerica',
#     'your',
#     'beauti',
#     'front',
#     'end',
#     'design',
#     'is',
#     'down',
#     'right',
#     'now',
#     'but',
#     'it',
#     'wa',
#     'cool',
#     'to',
#     'still',
#     'book',
#     'my',
#     'ticket',
#     'all',
#     'your',
#     'back',
#     'end',
#     'wa',
#     'secur'],
#    ['virginamerica',
#     'thank',
#     'to',
#     'your',
#     'outstand',
#     'nyc',
#     'jfk',
#     'crew',
#     'who',
#     'move',
#     'mountain',
#     'to',
#     'get',
#     'me',
#     'home',
#     'to',
#     'san',
#     'francisco',
#     'tonight']],
#   ['virginamerica',
#    'love',
#    'the',
#    'team',
#    'run',
#    'gate',
#    'at',
#    'la',
#    'tonight',
#    'wait',
#    'for',
#    'delay',
#    'flight',
#    'and',
#    'they',
#    'kept',
#    'thing',
#    'entertain']),
#  ([['virginamerica',
#     'your',
#     'beauti',
#     'front',
#     'end',
#     'design',
#     'is',
#     'down',
#     'right',
#     'now',
#     'but',
#     'it',
#     'wa',
#     'cool',
#     'to',
#     'still',
#     'book',
#     'my',
#     'ticket',
#     'all',
#     'your',
#     'back',
#     'end',
#     'wa',
#     'secur'],
#    ['virginamerica',
#     'love',
#     'the',
#     'team',
#     'run',
#     'gate',
#     'at',
#     'la',
#     'tonight',
#     'wait',
#     'for',
#     'delay',
#     'flight',
#     'and',
#     'they',
#     'kept',
#     'thing',
#     'entertain'],
#    ['virginamerica',
#     'you',
#     'have',
#     'the',
#     'absolut',
#     'best',
#     'team',
#     'and',
#     'custom',
#     'servic',
#     'ever',
#     'everi',
#     'time',
#     'fli',
#     'with',
#     'you',
#     'delight',
#     'thank',
#     'you']],
#   ['virginamerica',
#    'thank',
#    'to',
#    'your',
#    'outstand',
#    'nyc',
#    'jfk',
#    'crew',
#    'who',
#    'move',
#    'mountain',
#    'to',
#    'get',
#    'me',
#    'home',
#    'to',
#    'san',
#    'francisco',
#    'tonight']),
#  ([['virginamerica',
#     'love',
#     'the',
#     'team',
#     'run',
#     'gate',
#     'at',
#     'la',
#     'tonight',
#     'wait',
#     'for',
#     'delay',
#     'flight',
#     'and',
#     'they',
#     'kept',
#     'thing',
#     'entertain'],
#    ['virginamerica',
#     'thank',
#     'to',
#     'your',
#     'outstand',
#     'nyc',
#     'jfk',
#     'crew',
#     'who',
#     'move',
#     'mountain',
#     'to',
#     'get',
#     'me',
#     'home',
#     'to',
#     'san',
#     'francisco',
#     'tonight'],
#    ['virginamerica',
#     'complet',
#     'awesom',
#     'experi',
#     'last',
#     'month',
#     'bo',
#     'la',
#     'nonstop',
#     'thank',
#     'for',
#     'such',
#     'an',
#     'awesom',
#     'flight',
#     'and',
#     'depart',
#     'time',
#     'vabeatsjblu']],
#   ['virginamerica',
#    'you',
#    'have',
#    'the',
#    'absolut',
#    'best',
#    'team',
#    'and',
#    'custom',
#    'servic',
#    'ever',
#    'everi',
#    'time',
#    'fli',
#    'with',
#    'you',
#    'delight',
#    'thank',
#    'you']),
#  ([['virginamerica',
#     'thank',
#     'to',
#     'your',
#     'outstand',
#     'nyc',
#     'jfk',
#     'crew',
#     'who',
#     'move',
#     'mountain',
#     'to',
#     'get',
#     'me',
#     'home',
#     'to',
#     'san',
#     'francisco',
#     'tonight'],
#    ['virginamerica',
#     'you',
#     'have',
#     'the',
#     'absolut',
#     'best',
#     'team',
#     'and',
#     'custom',
#     'servic',
#     'ever',
#     'everi',
#     'time',
#     'fli',
#     'with',
#     'you',
#     'delight',
#     'thank',
#     'you'],
#    ['virginamerica',
#     'you',
#     'rock',
#     'for',
#     'make',
#     'it',
#     'so',
#     'can',
#     'watch',
#     'oscar',
#     'on',
#     'my',
#     'flight',
#     'redcarpet',
#     'oscar',
#     'oscar']],
#   ['virginamerica',
#    'complet',
#    'awesom',
#    'experi',
#    'last',
#    'month',
#    'bo',
#    'la',
#    'nonstop',
#    'thank',
#    'for',
#    'such',
#    'an',
#    'awesom',
#    'flight',
#    'and',
#    'depart',
#    'time',
#    'vabeatsjblu']),
#  ([['virginamerica',
#     'you',
#     'have',
#     'the',
#     'absolut',
#     'best',
#     'team',
#     'and',
#     'custom',
#     'servic',
#     'ever',
#     'everi',
#     'time',
#     'fli',
#     'with',
#     'you',
#     'delight',
#     'thank',
#     'you'],
#    ['virginamerica',
#     'complet',
#     'awesom',
#     'experi',
#     'last',
#     'month',
#     'bo',
#     'la',
#     'nonstop',
#     'thank',
#     'for',
#     'such',
#     'an',
#     'awesom',
#     'flight',
#     'and',
#     'depart',
#     'time',
#     'vabeatsjblu'],
#    ['virginamerica', 'alway', 'xoxo']],
#   ['virginamerica',
#    'you',
#    'rock',
#    'for',
#    'make',
#    'it',
#    'so',
#    'can',
#    'watch',
#    'oscar',
#    'on',
#    'my',
#    'flight',
#    'redcarpet',
#    'oscar',
#    'oscar']),
#  ([['virginamerica',
#     'complet',
#     'awesom',
#     'experi',
#     'last',
#     'month',
#     'bo',
#     'la',
#     'nonstop',
#     'thank',
#     'for',
#     'such',
#     'an',
#     'awesom',
#     'flight',
#     'and',
#     'depart',
#     'time',
#     'vabeatsjblu'],
#    ['virginamerica',
#     'you',
#     'rock',
#     'for',
#     'make',
#     'it',
#     'so',
#     'can',
#     'watch',
#     'oscar',
#     'on',
#     'my',
#     'flight',
#     'redcarpet',
#     'oscar',
#     'oscar'],
#    ['virginamerica',
#     'best',
#     'custom',
#     'servic',
#     'rep',
#     'in',
#     'the',
#     'world',
#     'irmafromdalla',
#     'take',
#     'the',
#     'cake']],
#   ['virginamerica', 'alway', 'xoxo']),
#  ([['virginamerica',
#     'you',
#     'rock',
#     'for',
#     'make',
#     'it',
#     'so',
#     'can',
#     'watch',
#     'oscar',
#     'on',
#     'my',
#     'flight',
#     'redcarpet',
#     'oscar',
#     'oscar'],
#    ['virginamerica', 'alway', 'xoxo'],
#    ['virginamerica',
#     'you',
#     'have',
#     'amaz',
#     'staff',
#     'amp',
#     'super',
#     'help',
#     'as',
#     'just',
#     'ran',
#     'the',
#     'waltdisneyworld',
#     'princesshalf',
#     'they',
#     'have',
#     'spoil',
#     'me',
#     'with',
#     'comfort']],
#   ['virginamerica',
#    'best',
#    'custom',
#    'servic',
#    'rep',
#    'in',
#    'the',
#    'world',
#    'irmafromdalla',
#    'take',
#    'the',
#    'cake']),
#  ([['virginamerica', 'alway', 'xoxo'],
#    ['virginamerica',
#     'best',
#     'custom',
#     'servic',
#     'rep',
#     'in',
#     'the',
#     'world',
#     'irmafromdalla',
#     'take',
#     'the',
#     'cake'],
#    ['alway',
#     'have',
#     'it',
#     'togeth',
#     'you',
#     're',
#     'welcom',
#     'rt',
#     'virginamerica',
#     'jessicajaym',
#     'you',
#     're',
#     'so',
#     'welcom']],
#   ['virginamerica',
#    'you',
#    'have',
#    'amaz',
#    'staff',
#    'amp',
#    'super',
#    'help',
#    'as',
#    'just',
#    'ran',
#    'the',
#    'waltdisneyworld',
#    'princesshalf',
#    'they',
#    'have',
#    'spoil',
#    'me',
#    'with',
#    'comfort']),
#  ([['virginamerica',
#     'best',
#     'custom',
#     'servic',
#     'rep',
#     'in',
#     'the',
#     'world',
#     'irmafromdalla',
#     'take',
#     'the',
#     'cake'],
#    ['virginamerica',
#     'you',
#     'have',
#     'amaz',
#     'staff',
#     'amp',
#     'super',
#     'help',
#     'as',
#     'just',
#     'ran',
#     'the',
#     'waltdisneyworld',
#     'princesshalf',
#     'they',
#     'have',
#     'spoil',
#     'me',
#     'with',
#     'comfort'],
#    ['virginamerica',
#     'flight',
#     'home',
#     'to',
#     'dc',
#     'sunset',
#     'globe',
#     'in',
#     'backtowint',
#     'back',
#     'to',
#     'work',
#     'refresh',
#     'http',
#     'co',
#     'vx',
#     'vbctdlf']],
#   ['alway',
#    'have',
#    'it',
#    'togeth',
#    'you',
#    're',
#    'welcom',
#    'rt',
#    'virginamerica',
#    'jessicajaym',
#    'you',
#    're',
#    'so',
#    'welcom']),
#  ([['virginamerica',
#     'you',
#     'have',
#     'amaz',
#     'staff',
#     'amp',
#     'super',
#     'help',
#     'as',
#     'just',
#     'ran',
#     'the',
#     'waltdisneyworld',
#     'princesshalf',
#     'they',
#     'have',
#     'spoil',
#     'me',
#     'with',
#     'comfort'],
#    ['alway',
#     'have',
#     'it',
#     'togeth',
#     'you',
#     're',
#     'welcom',
#     'rt',
#     'virginamerica',
#     'jessicajaym',
#     'you',
#     're',
#     'so',
#     'welcom'],
#    ['virginamerica',
#     'thank',
#     'you',
#     'for',
#     'check',
#     'in',
#     'ticket',
#     'are',
#     'purchas',
#     'and',
#     'custom',
#     'is',
#     'happi']],
#   ['virginamerica',
#    'flight',
#    'home',
#    'to',
#    'dc',
#    'sunset',
#    'globe',
#    'in',
#    'backtowint',
#    'back',
#    'to',
#    'work',
#    'refresh',
#    'http',
#    'co',
#    'vx',
#    'vbctdlf']),
#  ([['alway',
#     'have',
#     'it',
#     'togeth',
#     'you',
#     're',
#     'welcom',
#     'rt',
#     'virginamerica',
#     'jessicajaym',
#     'you',
#     're',
#     'so',
#     'welcom'],
#    ['virginamerica',
#     'flight',
#     'home',
#     'to',
#     'dc',
#     'sunset',
#     'globe',
#     'in',
#     'backtowint',
#     'back',
#     'to',
#     'work',
#     'refresh',
#     'http',
#     'co',
#     'vx',
#     'vbctdlf'],
#    ['virginamerica', 'thank', 'you', 'for', 'the', 'follow']],
#   ['virginamerica',
#    'thank',
#    'you',
#    'for',
#    'check',
#    'in',
#    'ticket',
#    'are',
#    'purchas',
#    'and',
#    'custom',
#    'is',
#    'happi']),
#  ([['virginamerica',
#     'flight',
#     'home',
#     'to',
#     'dc',
#     'sunset',
#     'globe',
#     'in',
#     'backtowint',
#     'back',
#     'to',
#     'work',
#     'refresh',
#     'http',
#     'co',
#     'vx',
#     'vbctdlf'],
#    ['virginamerica',
#     'thank',
#     'you',
#     'for',
#     'check',
#     'in',
#     'ticket',
#     'are',
#     'purchas',
#     'and',
#     'custom',
#     'is',
#     'happi'],
#    ['rt',
#     'virginamerica',
#     'you',
#     've',
#     'met',
#     'your',
#     'match',
#     'got',
#     'statu',
#     'on',
#     'anoth',
#     'airlin',
#     'upgrad',
#     'restr',
#     'http',
#     'co',
#     'rhkamx',
#     'vf',
#     'http',
#     'co',
#     'pyalebgkjt']],
#   ['virginamerica', 'thank', 'you', 'for', 'the', 'follow']),
#  ([['virginamerica',
#     'thank',
#     'you',
#     'for',
#     'check',
#     'in',
#     'ticket',
#     'are',
#     'purchas',
#     'and',
#     'custom',
#     'is',
#     'happi'],
#    ['virginamerica', 'thank', 'you', 'for', 'the', 'follow'],
#    ['virginamerica', 'onli', 'way', 'to', 'fli', 'elev', 'gold']],
#   ['rt',
#    'virginamerica',
#    'you',
#    've',
#    'met',
#    'your',
#    'match',
#    'got',
#    'statu',
#    'on',
#    'anoth',
#    'airlin',
#    'upgrad',
#    'restr',
#    'http',
#    'co',
#    'rhkamx',
#    'vf',
#    'http',
#    'co',
#    'pyalebgkjt']),
#  ([['virginamerica', 'thank', 'you', 'for', 'the', 'follow'],
#    ['rt',
#     'virginamerica',
#     'you',
#     've',
#     'met',
#     'your',
#     'match',
#     'got',
#     'statu',
#     'on',
#     'anoth',
#     'airlin',
#     'upgrad',
#     'restr',
#     'http',
#     'co',
#     'rhkamx',
#     'vf',
#     'http',
#     'co',
#     'pyalebgkjt'],
#    ['virginamerica', 'you', 'will', 'match', 'my', 'statu', 'cool']],
#   ['virginamerica', 'onli', 'way', 'to', 'fli', 'elev', 'gold']),
#  ([['rt',
#     'virginamerica',
#     'you',
#     've',
#     'met',
#     'your',
#     'match',
#     'got',
#     'statu',
#     'on',
#     'anoth',
#     'airlin',
#     'upgrad',
#     'restr',
#     'http',
#     'co',
#     'rhkamx',
#     'vf',
#     'http',
#     'co',
#     'pyalebgkjt'],
#    ['virginamerica', 'onli', 'way', 'to', 'fli', 'elev', 'gold'],
#    ['virginamerica', 'thank']],
#   ['virginamerica', 'you', 'will', 'match', 'my', 'statu', 'cool']),
#  ([['virginamerica', 'onli', 'way', 'to', 'fli', 'elev', 'gold'],
#    ['virginamerica', 'you', 'will', 'match', 'my', 'statu', 'cool'],
#    ['virginamerica',
#     'love',
#     'your',
#     'guy',
#     'song',
#     'we',
#     're',
#     'danc',
#     'to',
#     'it',
#     'for',
#     'our',
#     'high',
#     'school',
#     'danc',
#     'revu']],
#   ['virginamerica', 'thank']),
#  ([['virginamerica', 'you', 'will', 'match', 'my', 'statu', 'cool'],
#    ['virginamerica', 'thank'],
#    ['virginamerica',
#     'done',
#     'thank',
#     'you',
#     'for',
#     'the',
#     'quick',
#     'respons',
#     'appar',
#     'faster',
#     'than',
#     'sit',
#     'on',
#     'hold']],
#   ['virginamerica',
#    'love',
#    'your',
#    'guy',
#    'song',
#    'we',
#    're',
#    'danc',
#    'to',
#    'it',
#    'for',
#    'our',
#    'high',
#    'school',
#    'danc',
#    'revu']),
#  ([['virginamerica', 'thank'],
#    ['virginamerica',
#     'love',
#     'your',
#     'guy',
#     'song',
#     'we',
#     're',
#     'danc',
#     'to',
#     'it',
#     'for',
#     'our',
#     'high',
#     'school',
#     'danc',
#     'revu'],
#    ['virginamerica',
#     'cool',
#     'pictur',
#     'of',
#     'anoth',
#     'virginamerica',
#     'plane',
#     'off',
#     'our',
#     'wing',
#     'what',
#     'site',
#     'http',
#     'co',
#     'agfd']],
#   ['virginamerica',
#    'done',
#    'thank',
#    'you',
#    'for',
#    'the',
#    'quick',
#    'respons',
#    'appar',
#    'faster',
#    'than',
#    'sit',
#    'on',
#    'hold']),
#  ([['virginamerica',
#     'love',
#     'your',
#     'guy',
#     'song',
#     'we',
#     're',
#     'danc',
#     'to',
#     'it',
#     'for',
#     'our',
#     'high',
#     'school',
#     'danc',
#     'revu'],
#    ['virginamerica',
#     'done',
#     'thank',
#     'you',
#     'for',
#     'the',
#     'quick',
#     'respons',
#     'appar',
#     'faster',
#     'than',
#     'sit',
#     'on',
#     'hold'],
#    ['virginamerica', 'keep', 'up', 'the', 'great', 'work']],
#   ['virginamerica',
#    'cool',
#    'pictur',
#    'of',
#    'anoth',
#    'virginamerica',
#    'plane',
#    'off',
#    'our',
#    'wing',
#    'what',
#    'site',
#    'http',
#    'co',
#    'agfd']),
#  ([['virginamerica',
#     'done',
#     'thank',
#     'you',
#     'for',
#     'the',
#     'quick',
#     'respons',
#     'appar',
#     'faster',
#     'than',
#     'sit',
#     'on',
#     'hold'],
#    ['virginamerica',
#     'cool',
#     'pictur',
#     'of',
#     'anoth',
#     'virginamerica',
#     'plane',
#     'off',
#     'our',
#     'wing',
#     'what',
#     'site',
#     'http',
#     'co',
#     'agfd'],
#    ['virginamerica',
#     'my',
#     'good',
#     'your',
#     'peopl',
#     'love',
#     'field',
#     'are',
#     'amaz',
#     'under',
#     'pressur',
#     'from',
#     'texa',
#     'beatstheoth',
#     'in',
#     'crisi',
#     'pleas',
#     'fli',
#     'me',
#     'to',
#     'ny']],
#   ['virginamerica', 'keep', 'up', 'the', 'great', 'work']),
#  ([['virginamerica',
#     'cool',
#     'pictur',
#     'of',
#     'anoth',
#     'virginamerica',
#     'plane',
#     'off',
#     'our',
#     'wing',
#     'what',
#     'site',
#     'http',
#     'co',
#     'agfd'],
#    ['virginamerica', 'keep', 'up', 'the', 'great', 'work'],
#    ['virginamerica',
#     'thank',
#     'for',
#     'great',
#     'flight',
#     'from',
#     'la',
#     'to',
#     'boston',
#     'pilot',
#     'did',
#     'great',
#     'job',
#     'land',
#     'in',
#     'the',
#     'snow',
#     'can',
#     'we',
#     'go',
#     'back',
#     'to',
#     'la',
#     'now',
#     'serious']],
#   ['virginamerica',
#    'my',
#    'good',
#    'your',
#    'peopl',
#    'love',
#    'field',
#    'are',
#    'amaz',
#    'under',
#    'pressur',
#    'from',
#    'texa',
#    'beatstheoth',
#    'in',
#    'crisi',
#    'pleas',
#    'fli',
#    'me',
#    'to',
#    'ny']),
#  ([['virginamerica', 'keep', 'up', 'the', 'great', 'work'],
#    ['virginamerica',
#     'my',
#     'good',
#     'your',
#     'peopl',
#     'love',
#     'field',
#     'are',
#     'amaz',
#     'under',
#     'pressur',
#     'from',
#     'texa',
#     'beatstheoth',
#     'in',
#     'crisi',
#     'pleas',
#     'fli',
#     'me',
#     'to',
#     'ny'],
#    ['virginamerica',
#     'thank',
#     'so',
#     'much',
#     'for',
#     'the',
#     'awesom',
#     'support',
#     'you',
#     'guy',
#     'rock']],
#   ['virginamerica',
#    'thank',
#    'for',
#    'great',
#    'flight',
#    'from',
#    'la',
#    'to',
#    'boston',
#    'pilot',
#    'did',
#    'great',
#    'job',
#    'land',
#    'in',
#    'the',
#    'snow',
#    'can',
#    'we',
#    'go',
#    'back',
#    'to',
#    'la',
#    'now',
#    'serious']),
#  ([['virginamerica',
#     'my',
#     'good',
#     'your',
#     'peopl',
#     'love',
#     'field',
#     'are',
#     'amaz',
#     'under',
#     'pressur',
#     'from',
#     'texa',
#     'beatstheoth',
#     'in',
#     'crisi',
#     'pleas',
#     'fli',
#     'me',
#     'to',
#     'ny'],
#    ['virginamerica',
#     'thank',
#     'for',
#     'great',
#     'flight',
#     'from',
#     'la',
#     'to',
#     'boston',
#     'pilot',
#     'did',
#     'great',
#     'job',
#     'land',
#     'in',
#     'the',
#     'snow',
#     'can',
#     'we',
#     'go',
#     'back',
#     'to',
#     'la',
#     'now',
#     'serious'],
#    ['virginamerica',
#     'twitter',
#     'team',
#     'you',
#     'guy',
#     'kill',
#     'it',
#     'for',
#     'reschedul',
#     'me',
#     'asap',
#     'thank',
#     'you']],
#   ['virginamerica',
#    'thank',
#    'so',
#    'much',
#    'for',
#    'the',
#    'awesom',
#    'support',
#    'you',
#    'guy',
#    'rock']),
#  ([['virginamerica',
#     'thank',
#     'for',
#     'great',
#     'flight',
#     'from',
#     'la',
#     'to',
#     'boston',
#     'pilot',
#     'did',
#     'great',
#     'job',
#     'land',
#     'in',
#     'the',
#     'snow',
#     'can',
#     'we',
#     'go',
#     'back',
#     'to',
#     'la',
#     'now',
#     'serious'],
#    ['virginamerica',
#     'thank',
#     'so',
#     'much',
#     'for',
#     'the',
#     'awesom',
#     'support',
#     'you',
#     'guy',
#     'rock'],
#    ['virginamerica',
#     'when',
#     'are',
#     'you',
#     'put',
#     'some',
#     'great',
#     'deal',
#     'from',
#     'pdx',
#     'to',
#     'la',
#     'or',
#     'from',
#     'la',
#     'to',
#     'pdx',
#     'show',
#     'me',
#     'your',
#     'love',
#     'http',
#     'co',
#     'eniqg',
#     'buzj']],
#   ['virginamerica',
#    'twitter',
#    'team',
#    'you',
#    'guy',
#    'kill',
#    'it',
#    'for',
#    'reschedul',
#    'me',
#    'asap',
#    'thank',
#    'you']),
#  ([['virginamerica',
#     'thank',
#     'so',
#     'much',
#     'for',
#     'the',
#     'awesom',
#     'support',
#     'you',
#     'guy',
#     'rock'],
#    ['virginamerica',
#     'twitter',
#     'team',
#     'you',
#     'guy',
#     'kill',
#     'it',
#     'for',
#     'reschedul',
#     'me',
#     'asap',
#     'thank',
#     'you'],
#    ['virginamerica',
#     'wish',
#     'can',
#     'afford',
#     'to',
#     'fli',
#     'with',
#     'you',
#     'next',
#     'friday',
#     'go',
#     'back',
#     'home',
#     'love',
#     'everyth',
#     'about',
#     'your',
#     'airlin']],
#   ['virginamerica',
#    'when',
#    'are',
#    'you',
#    'put',
#    'some',
#    'great',
#    'deal',
#    'from',
#    'pdx',
#    'to',
#    'la',
#    'or',
#    'from',
#    'la',
#    'to',
#    'pdx',
#    'show',
#    'me',
#    'your',
#    'love',
#    'http',
#    'co',
#    'eniqg',
#    'buzj']),
#  ([['virginamerica',
#     'twitter',
#     'team',
#     'you',
#     'guy',
#     'kill',
#     'it',
#     'for',
#     'reschedul',
#     'me',
#     'asap',
#     'thank',
#     'you'],
#    ['virginamerica',
#     'when',
#     'are',
#     'you',
#     'put',
#     'some',
#     'great',
#     'deal',
#     'from',
#     'pdx',
#     'to',
#     'la',
#     'or',
#     'from',
#     'la',
#     'to',
#     'pdx',
#     'show',
#     'me',
#     'your',
#     'love',
#     'http',
#     'co',
#     'eniqg',
#     'buzj'],
#    ['virginamerica', 'like', 'http', 'co', 'vpqem', 'xuq']],
#   ['virginamerica',
#    'wish',
#    'can',
#    'afford',
#    'to',
#    'fli',
#    'with',
#    'you',
#    'next',
#    'friday',
#    'go',
#    'back',
#    'home',
#    'love',
#    'everyth',
#    'about',
#    'your',
#    'airlin']),
#  ([['virginamerica',
#     'when',
#     'are',
#     'you',
#     'put',
#     'some',
#     'great',
#     'deal',
#     'from',
#     'pdx',
#     'to',
#     'la',
#     'or',
#     'from',
#     'la',
#     'to',
#     'pdx',
#     'show',
#     'me',
#     'your',
#     'love',
#     'http',
#     'co',
#     'eniqg',
#     'buzj'],
#    ['virginamerica',
#     'wish',
#     'can',
#     'afford',
#     'to',
#     'fli',
#     'with',
#     'you',
#     'next',
#     'friday',
#     'go',
#     'back',
#     'home',
#     'love',
#     'everyth',
#     'about',
#     'your',
#     'airlin'],
#    ['virginamerica',
#     'you',
#     'have',
#     'the',
#     'best',
#     'flight',
#     'attend',
#     'ever',
#     'http',
#     'co',
#     'pxdel',
#     'nq']],
#   ['virginamerica', 'like', 'http', 'co', 'vpqem', 'xuq']),
#  ([['virginamerica',
#     'wish',
#     'can',
#     'afford',
#     'to',
#     'fli',
#     'with',
#     'you',
#     'next',
#     'friday',
#     'go',
#     'back',
#     'home',
#     'love',
#     'everyth',
#     'about',
#     'your',
#     'airlin'],
#    ['virginamerica', 'like', 'http', 'co', 'vpqem', 'xuq'],
#    ['awesom',
#     'rt',
#     'virginamerica',
#     'watch',
#     'nomin',
#     'film',
#     'at',
#     'feet',
#     'meetthefleet',
#     'oscar',
#     'http',
#     'co',
#     'dnstitrzwi']],
#   ['virginamerica',
#    'you',
#    'have',
#    'the',
#    'best',
#    'flight',
#    'attend',
#    'ever',
#    'http',
#    'co',
#    'pxdel',
#    'nq']),
#  ([['virginamerica', 'like', 'http', 'co', 'vpqem', 'xuq'],
#    ['virginamerica',
#     'you',
#     'have',
#     'the',
#     'best',
#     'flight',
#     'attend',
#     'ever',
#     'http',
#     'co',
#     'pxdel',
#     'nq'],
#    ['virginamerica', 'thank', 'so', 'much']],
#   ['awesom',
#    'rt',
#    'virginamerica',
#    'watch',
#    'nomin',
#    'film',
#    'at',
#    'feet',
#    'meetthefleet',
#    'oscar',
#    'http',
#    'co',
#    'dnstitrzwi']),
#  ([['virginamerica',
#     'you',
#     'have',
#     'the',
#     'best',
#     'flight',
#     'attend',
#     'ever',
#     'http',
#     'co',
#     'pxdel',
#     'nq'],
#    ['awesom',
#     'rt',
#     'virginamerica',
#     'watch',
#     'nomin',
#     'film',
#     'at',
#     'feet',
#     'meetthefleet',
#     'oscar',
#     'http',
#     'co',
#     'dnstitrzwi'],
#    ['virginamerica',
#     'the',
#     'onli',
#     'airlin',
#     'base',
#     'in',
#     'silicon',
#     'valley',
#     'disrupt',
#     'incub',
#     'fastcompani',
#     'http',
#     'co',
#     'wu',
#     'lbcncr']],
#   ['virginamerica', 'thank', 'so', 'much']),
#  ([['awesom',
#     'rt',
#     'virginamerica',
#     'watch',
#     'nomin',
#     'film',
#     'at',
#     'feet',
#     'meetthefleet',
#     'oscar',
#     'http',
#     'co',
#     'dnstitrzwi'],
#    ['virginamerica', 'thank', 'so', 'much'],
#    ['virginamerica', 'veri', 'nice', 'done']],
#   ['virginamerica',
#    'the',
#    'onli',
#    'airlin',
#    'base',
#    'in',
#    'silicon',
#    'valley',
#    'disrupt',
#    'incub',
#    'fastcompani',
#    'http',
#    'co',
#    'wu',
#    'lbcncr']),
#  ([['virginamerica', 'thank', 'so', 'much'],
#    ['virginamerica',
#     'the',
#     'onli',
#     'airlin',
#     'base',
#     'in',
#     'silicon',
#     'valley',
#     'disrupt',
#     'incub',
#     'fastcompani',
#     'http',
#     'co',
#     'wu',
#     'lbcncr'],
#    ['virginamerica',
#     'look',
#     'forward',
#     'to',
#     'watch',
#     'the',
#     'oscar',
#     'on',
#     'my',
#     'flight',
#     'home',
#     'tomorrow',
#     'might',
#     'even',
#     'get',
#     'someth',
#     'bubbl',
#     'to',
#     'drink']],
#   ['virginamerica', 'veri', 'nice', 'done']),
#  ([['virginamerica',
#     'the',
#     'onli',
#     'airlin',
#     'base',
#     'in',
#     'silicon',
#     'valley',
#     'disrupt',
#     'incub',
#     'fastcompani',
#     'http',
#     'co',
#     'wu',
#     'lbcncr'],
#    ['virginamerica', 'veri', 'nice', 'done'],
#    ['virginamerica',
#     'hahaha',
#     'virginamerica',
#     'you',
#     'guy',
#     'are',
#     'amaz',
#     'love',
#     'you',
#     'guy']],
#   ['virginamerica',
#    'look',
#    'forward',
#    'to',
#    'watch',
#    'the',
#    'oscar',
#    'on',
#    'my',
#    'flight',
#    'home',
#    'tomorrow',
#    'might',
#    'even',
#    'get',
#    'someth',
#    'bubbl',
#    'to',
#    'drink']),
#  ([['virginamerica', 'veri', 'nice', 'done'],
#    ['virginamerica',
#     'look',
#     'forward',
#     'to',
#     'watch',
#     'the',
#     'oscar',
#     'on',
#     'my',
#     'flight',
#     'home',
#     'tomorrow',
#     'might',
#     'even',
#     'get',
#     'someth',
#     'bubbl',
#     'to',
#     'drink'],
#    ['virginamerica', 'sound', 'like', 'fun']],
#   ['virginamerica',
#    'hahaha',
#    'virginamerica',
#    'you',
#    'guy',
#    'are',
#    'amaz',
#    'love',
#    'you',
#    'guy']),
#  ([['virginamerica',
#     'look',
#     'forward',
#     'to',
#     'watch',
#     'the',
#     'oscar',
#     'on',
#     'my',
#     'flight',
#     'home',
#     'tomorrow',
#     'might',
#     'even',
#     'get',
#     'someth',
#     'bubbl',
#     'to',
#     'drink'],
#    ['virginamerica',
#     'hahaha',
#     'virginamerica',
#     'you',
#     'guy',
#     'are',
#     'amaz',
#     'love',
#     'you',
#     'guy'],
#    ['virginamerica', 'classiq', 'luv', 'virgin', 'america', 'greetingz']],
#   ['virginamerica', 'sound', 'like', 'fun']),
#  ([['virginamerica',
#     'hahaha',
#     'virginamerica',
#     'you',
#     'guy',
#     'are',
#     'amaz',
#     'love',
#     'you',
#     'guy'],
#    ['virginamerica', 'sound', 'like', 'fun'],
#    ['virginamerica',
#     'thank',
#     'for',
#     'your',
#     'great',
#     'custom',
#     'servic',
#     'today',
#     'amp',
#     'for',
#     'help',
#     'me',
#     'get',
#     'all',
#     'my',
#     'travel',
#     'sort',
#     'out']],
#   ['virginamerica', 'classiq', 'luv', 'virgin', 'america', 'greetingz']),
#  ([['virginamerica', 'sound', 'like', 'fun'],
#    ['virginamerica', 'classiq', 'luv', 'virgin', 'america', 'greetingz'],
#    ['virginamerica', 'thank', 'guy', 'sweet', 'rout', 'over', 'the', 'rocki']],
#   ['virginamerica',
#    'thank',
#    'for',
#    'your',
#    'great',
#    'custom',
#    'servic',
#    'today',
#    'amp',
#    'for',
#    'help',
#    'me',
#    'get',
#    'all',
#    'my',
#    'travel',
#    'sort',
#    'out']),
#  ([['virginamerica', 'classiq', 'luv', 'virgin', 'america', 'greetingz'],
#    ['virginamerica',
#     'thank',
#     'for',
#     'your',
#     'great',
#     'custom',
#     'servic',
#     'today',
#     'amp',
#     'for',
#     'help',
#     'me',
#     'get',
#     'all',
#     'my',
#     'travel',
#     'sort',
#     'out'],
#    ['virginamerica',
#     'love',
#     'the',
#     'music',
#     'blast',
#     'at',
#     'gate',
#     'in',
#     'boston',
# ...
#     'you',
#     'are',
#     'forgiven',
#     'most',
#     'love',
#     'custom',
#     'it',
#     'as',
#     'if',
#     'you',
#     'never',
#     'left',
#     'll',
#     'that',
#     'whi',
#     'you',
#     're',
#     'bae'],
#    ['southwestair',
#     'sorri',
#     'to',
#     'spam',
#     'it',
#     'would',
#     'just',
#     'be',
#     'so',
#     'awesom',
#     'to',
#     'see',
#     'imaginedragon',
#     'in',
#     'vega',
#     'your',
#     'help',
#     'would',
#     'be',
#     'absolut',
#     'amaz']],
#   ['southwestair',
#    'you',
#    'onli',
#    'hear',
#    'about',
#    'the',
#    'bad',
#    'thing',
#    'fli',
#    'the',
#    'last',
#    'to',
#    'weekend',
#    'the',
#    'flight',
#    'and',
#    'crew',
#    'were',
#    'awesom',
#    'thank',
#    'you']),
#  ([['southwestair',
#     'amiltx',
#     'you',
#     'are',
#     'forgiven',
#     'most',
#     'love',
#     'custom',
#     'it',
#     'as',
#     'if',
#     'you',
#     'never',
#     'left',
#     'll',
#     'that',
#     'whi',
#     'you',
#     're',
#     'bae'],
#    ['southwestair',
#     'you',
#     'onli',
#     'hear',
#     'about',
#     'the',
#     'bad',
#     'thing',
#     'fli',
#     'the',
#     'last',
#     'to',
#     'weekend',
#     'the',
#     'flight',
#     'and',
#     'crew',
#     'were',
#     'awesom',
#     'thank',
#     'you'],
#    ['southwestair',
#     'michaelbcoleman',
#     'thank',
#     'for',
#     'make',
#     'new',
#     'direct',
#     'flight',
#     'to',
#     'san',
#     'francisco']],
#   ['southwestair',
#    'sorri',
#    'to',
#    'spam',
#    'it',
#    'would',
#    'just',
#    'be',
#    'so',
#    'awesom',
#    'to',
#    'see',
#    'imaginedragon',
#    'in',
#    'vega',
#    'your',
#    'help',
#    'would',
#    'be',
#    'absolut',
#    'amaz']),
#  ([['southwestair',
#     'you',
#     'onli',
#     'hear',
#     'about',
#     'the',
#     'bad',
#     'thing',
#     'fli',
#     'the',
#     'last',
#     'to',
#     'weekend',
#     'the',
#     'flight',
#     'and',
#     'crew',
#     'were',
#     'awesom',
#     'thank',
#     'you'],
#    ['southwestair',
#     'sorri',
#     'to',
#     'spam',
#     'it',
#     'would',
#     'just',
#     'be',
#     'so',
#     'awesom',
#     'to',
#     'see',
#     'imaginedragon',
#     'in',
#     'vega',
#     'your',
#     'help',
#     'would',
#     'be',
#     'absolut',
#     'amaz'],
#    ['southwestair',
#     'the',
#     'crew',
#     'of',
#     'ha',
#     'been',
#     'great',
#     'to',
#     'us',
#     'today',
#     'travel',
#     'from',
#     'ft',
#     'lauderdal',
#     'to',
#     'louisvil',
#     'with',
#     'kid',
#     'and',
#     'under',
#     'thank']],
#   ['southwestair',
#    'michaelbcoleman',
#    'thank',
#    'for',
#    'make',
#    'new',
#    'direct',
#    'flight',
#    'to',
#    'san',
#    'francisco']),
#  ([['southwestair',
#     'sorri',
#     'to',
#     'spam',
#     'it',
#     'would',
#     'just',
#     'be',
#     'so',
#     'awesom',
#     'to',
#     'see',
#     'imaginedragon',
#     'in',
#     'vega',
#     'your',
#     'help',
#     'would',
#     'be',
#     'absolut',
#     'amaz'],
#    ['southwestair',
#     'michaelbcoleman',
#     'thank',
#     'for',
#     'make',
#     'new',
#     'direct',
#     'flight',
#     'to',
#     'san',
#     'francisco'],
#    ['southwestair',
#     'nvm',
#     'gate',
#     'said',
#     'they',
#     're',
#     'hold',
#     'connect',
#     'thank',
#     'for',
#     'quick',
#     'respons']],
#   ['southwestair',
#    'the',
#    'crew',
#    'of',
#    'ha',
#    'been',
#    'great',
#    'to',
#    'us',
#    'today',
#    'travel',
#    'from',
#    'ft',
#    'lauderdal',
#    'to',
#    'louisvil',
#    'with',
#    'kid',
#    'and',
#    'under',
#    'thank']),
#  ([['southwestair',
#     'michaelbcoleman',
#     'thank',
#     'for',
#     'make',
#     'new',
#     'direct',
#     'flight',
#     'to',
#     'san',
#     'francisco'],
#    ['southwestair',
#     'the',
#     'crew',
#     'of',
#     'ha',
#     'been',
#     'great',
#     'to',
#     'us',
#     'today',
#     'travel',
#     'from',
#     'ft',
#     'lauderdal',
#     'to',
#     'louisvil',
#     'with',
#     'kid',
#     'and',
#     'under',
#     'thank'],
#    ['southwestair',
#     'look',
#     'forward',
#     'to',
#     'the',
#     'beat',
#     'music',
#     'avail',
#     'on',
#     'my',
#     'flight',
#     'today',
#     'that',
#     'pretti',
#     'cool']],
#   ['southwestair',
#    'nvm',
#    'gate',
#    'said',
#    'they',
#    're',
#    'hold',
#    'connect',
#    'thank',
#    'for',
#    'quick',
#    'respons']),
#  ([['southwestair',
#     'the',
#     'crew',
#     'of',
#     'ha',
#     'been',
#     'great',
#     'to',
#     'us',
#     'today',
#     'travel',
#     'from',
#     'ft',
#     'lauderdal',
#     'to',
#     'louisvil',
#     'with',
#     'kid',
#     'and',
#     'under',
#     'thank'],
#    ['southwestair',
#     'nvm',
#     'gate',
#     'said',
#     'they',
#     're',
#     'hold',
#     'connect',
#     'thank',
#     'for',
#     'quick',
#     'respons'],
#    ['southwestair',
#     'ha',
#     'some',
#     'of',
#     'the',
#     'best',
#     'airfar',
#     'price',
#     'gotta',
#     'luv',
#     'them']],
#   ['southwestair',
#    'look',
#    'forward',
#    'to',
#    'the',
#    'beat',
#    'music',
#    'avail',
#    'on',
#    'my',
#    'flight',
#    'today',
#    'that',
#    'pretti',
#    'cool']),
#  ([['southwestair',
#     'nvm',
#     'gate',
#     'said',
#     'they',
#     're',
#     'hold',
#     'connect',
#     'thank',
#     'for',
#     'quick',
#     'respons'],
#    ['southwestair',
#     'look',
#     'forward',
#     'to',
#     'the',
#     'beat',
#     'music',
#     'avail',
#     'on',
#     'my',
#     'flight',
#     'today',
#     'that',
#     'pretti',
#     'cool'],
#    ['southwestair', 'thank', 'you', 'will', 'do']],
#   ['southwestair',
#    'ha',
#    'some',
#    'of',
#    'the',
#    'best',
#    'airfar',
#    'price',
#    'gotta',
#    'luv',
#    'them']),
#  ([['southwestair',
#     'look',
#     'forward',
#     'to',
#     'the',
#     'beat',
#     'music',
#     'avail',
#     'on',
#     'my',
#     'flight',
#     'today',
#     'that',
#     'pretti',
#     'cool'],
#    ['southwestair',
#     'ha',
#     'some',
#     'of',
#     'the',
#     'best',
#     'airfar',
#     'price',
#     'gotta',
#     'luv',
#     'them'],
#    ['southwestair', 'thank', 'for', 'the', 'opportun']],
#   ['southwestair', 'thank', 'you', 'will', 'do']),
#  ([['southwestair',
#     'ha',
#     'some',
#     'of',
#     'the',
#     'best',
#     'airfar',
#     'price',
#     'gotta',
#     'luv',
#     'them'],
#    ['southwestair', 'thank', 'you', 'will', 'do'],
#    ['southwestair',
#     'truli',
#     'the',
#     'best',
#     'in',
#     'customerservic',
#     'if',
#     'someth',
#     'goe',
#     'wrong',
#     'no',
#     'matter',
#     'how',
#     'big',
#     'or',
#     'small',
#     'the',
#     'issu',
#     'wa',
#     'they',
#     'fix',
#     'it',
#     'thank',
#     'you']],
#   ['southwestair', 'thank', 'for', 'the', 'opportun']),
#  ([['southwestair', 'thank', 'you', 'will', 'do'],
#    ['southwestair', 'thank', 'for', 'the', 'opportun'],
#    ['southwestair',
#     'you',
#     'are',
#     'the',
#     'easiest',
#     'airlin',
#     'to',
#     'deal',
#     'with',
#     'loveee',
#     'you',
#     'so',
#     'much']],
#   ['southwestair',
#    'truli',
#    'the',
#    'best',
#    'in',
#    'customerservic',
#    'if',
#    'someth',
#    'goe',
#    'wrong',
#    'no',
#    'matter',
#    'how',
#    'big',
#    'or',
#    'small',
#    'the',
#    'issu',
#    'wa',
#    'they',
#    'fix',
#    'it',
#    'thank',
#    'you']),
#  ([['southwestair', 'thank', 'for', 'the', 'opportun'],
#    ['southwestair',
#     'truli',
#     'the',
#     'best',
#     'in',
#     'customerservic',
#     'if',
#     'someth',
#     'goe',
#     'wrong',
#     'no',
#     'matter',
#     'how',
#     'big',
#     'or',
#     'small',
#     'the',
#     'issu',
#     'wa',
#     'they',
#     'fix',
#     'it',
#     'thank',
#     'you'],
#    ['southwestair', 'thank', 'you']],
#   ['southwestair',
#    'you',
#    'are',
#    'the',
#    'easiest',
#    'airlin',
#    'to',
#    'deal',
#    'with',
#    'loveee',
#    'you',
#    'so',
#    'much']),
#  ([['southwestair',
#     'truli',
#     'the',
#     'best',
#     'in',
#     'customerservic',
#     'if',
#     'someth',
#     'goe',
#     'wrong',
#     'no',
#     'matter',
#     'how',
#     'big',
#     'or',
#     'small',
#     'the',
#     'issu',
#     'wa',
#     'they',
#     'fix',
#     'it',
#     'thank',
#     'you'],
#    ['southwestair',
#     'you',
#     'are',
#     'the',
#     'easiest',
#     'airlin',
#     'to',
#     'deal',
#     'with',
#     'loveee',
#     'you',
#     'so',
#     'much'],
#    ['southwestair', 'ok', 'gotcha']],
#   ['southwestair', 'thank', 'you']),
#  ([['southwestair',
#     'you',
#     'are',
#     'the',
#     'easiest',
#     'airlin',
#     'to',
#     'deal',
#     'with',
#     'loveee',
#     'you',
#     'so',
#     'much'],
#    ['southwestair', 'thank', 'you'],
#    ['southwestair',
#     'excit',
#     'too',
#     'but',
#     'perhap',
#     'you',
#     'could',
#     'scale',
#     'your',
#     'excit',
#     'back',
#     'by',
#     'few',
#     'week']],
#   ['southwestair', 'ok', 'gotcha']),
#  ([['southwestair', 'thank', 'you'],
#    ['southwestair', 'ok', 'gotcha'],
#    ['southwestair',
#     'me',
#     'amp',
#     'sammi_jon',
#     'are',
#     'best',
#     'friend',
#     'becaus',
#     'of',
#     'imaginedragon',
#     'ani',
#     'chanc',
#     'we',
#     'could',
#     'get',
#     'ticket',
#     'to']],
#   ['southwestair',
#    'excit',
#    'too',
#    'but',
#    'perhap',
#    'you',
#    'could',
#    'scale',
#    'your',
#    'excit',
#    'back',
#    'by',
#    'few',
#    'week']),
#  ([['southwestair', 'ok', 'gotcha'],
#    ['southwestair',
#     'excit',
#     'too',
#     'but',
#     'perhap',
#     'you',
#     'could',
#     'scale',
#     'your',
#     'excit',
#     'back',
#     'by',
#     'few',
#     'week'],
#    ['southwestair', 'thank', 'you', 'you', 'guy']],
#   ['southwestair',
#    'me',
#    'amp',
#    'sammi_jon',
#    'are',
#    'best',
#    'friend',
#    'becaus',
#    'of',
#    'imaginedragon',
#    'ani',
#    'chanc',
#    'we',
#    'could',
#    'get',
#    'ticket',
#    'to']),
#  ([['southwestair',
#     'excit',
#     'too',
#     'but',
#     'perhap',
#     'you',
#     'could',
#     'scale',
#     'your',
#     'excit',
#     'back',
#     'by',
#     'few',
#     'week'],
#    ['southwestair',
#     'me',
#     'amp',
#     'sammi_jon',
#     'are',
#     'best',
#     'friend',
#     'becaus',
#     'of',
#     'imaginedragon',
#     'ani',
#     'chanc',
#     'we',
#     'could',
#     'get',
#     'ticket',
#     'to'],
#    ['southwestair',
#     'ceo',
#     'gari',
#     'kelli',
#     'we',
#     'are',
#     'america',
#     'most',
#     'love',
#     'and',
#     'most',
#     'flown',
#     'airlin',
#     'southwestr',
#     'bwi',
#     'bestemploye',
#     'swacultur',
#     'swapic']],
#   ['southwestair', 'thank', 'you', 'you', 'guy']),
#  ([['southwestair',
#     'me',
#     'amp',
#     'sammi_jon',
#     'are',
#     'best',
#     'friend',
#     'becaus',
#     'of',
#     'imaginedragon',
#     'ani',
#     'chanc',
#     'we',
#     'could',
#     'get',
#     'ticket',
#     'to'],
#    ['southwestair', 'thank', 'you', 'you', 'guy'],
#    ['southwestair',
#     'dresparkl',
#     'thank',
#     'you',
#     'final',
#     'made',
#     'it',
#     'to',
#     'my',
#     'destin']],
#   ['southwestair',
#    'ceo',
#    'gari',
#    'kelli',
#    'we',
#    'are',
#    'america',
#    'most',
#    'love',
#    'and',
#    'most',
#    'flown',
#    'airlin',
#    'southwestr',
#    'bwi',
#    'bestemploye',
#    'swacultur',
#    'swapic']),
#  ([['southwestair', 'thank', 'you', 'you', 'guy'],
#    ['southwestair',
#     'ceo',
#     'gari',
#     'kelli',
#     'we',
#     'are',
#     'america',
#     'most',
#     'love',
#     'and',
#     'most',
#     'flown',
#     'airlin',
#     'southwestr',
#     'bwi',
#     'bestemploye',
#     'swacultur',
#     'swapic'],
#    ['southwestair',
#     'luvin',
#     'me',
#     'some',
#     'flight',
#     'today',
#     'don',
#     'chang',
#     'and',
#     'pleas',
#     'add',
#     'paypal',
#     'as',
#     'payment',
#     'option']],
#   ['southwestair',
#    'dresparkl',
#    'thank',
#    'you',
#    'final',
#    'made',
#    'it',
#    'to',
#    'my',
#    'destin']),
#  ([['southwestair',
#     'ceo',
#     'gari',
#     'kelli',
#     'we',
#     'are',
#     'america',
#     'most',
#     'love',
#     'and',
#     'most',
#     'flown',
#     'airlin',
#     'southwestr',
#     'bwi',
#     'bestemploye',
#     'swacultur',
#     'swapic'],
#    ['southwestair',
#     'dresparkl',
#     'thank',
#     'you',
#     'final',
#     'made',
#     'it',
#     'to',
#     'my',
#     'destin'],
#    ['southwestair',
#     'make',
#     'fli',
#     'for',
#     'uno_basebal',
#     'fun',
#     'flight',
#     'crew',
#     'just',
#     'led',
#     'the',
#     'plane',
#     'in',
#     'sing',
#     'happi',
#     'birthday',
#     'to',
#     'one',
#     'of',
#     'our',
#     'guy',
#     'luvintheair']],
#   ['southwestair',
#    'luvin',
#    'me',
#    'some',
#    'flight',
#    'today',
#    'don',
#    'chang',
#    'and',
#    'pleas',
#    'add',
#    'paypal',
#    'as',
#    'payment',
#    'option']),
#  ([['southwestair',
#     'dresparkl',
#     'thank',
#     'you',
#     'final',
#     'made',
#     'it',
#     'to',
#     'my',
#     'destin'],
#    ['southwestair',
#     'luvin',
#     'me',
#     'some',
#     'flight',
#     'today',
#     'don',
#     'chang',
#     'and',
#     'pleas',
#     'add',
#     'paypal',
#     'as',
#     'payment',
#     'option'],
#    ['southwestair',
#     'just',
#     'receiv',
#     'your',
#     'birthday',
#     'card',
#     'it',
#     'wa',
#     'amaz',
#     'and',
#     'made',
#     'me',
#     'smile',
#     'with',
#     'joy',
#     'nice',
#     'video',
#     'thank']],
#   ['southwestair',
#    'make',
#    'fli',
#    'for',
#    'uno_basebal',
#    'fun',
#    'flight',
#    'crew',
#    'just',
#    'led',
#    'the',
#    'plane',
#    'in',
#    'sing',
#    'happi',
#    'birthday',
#    'to',
#    'one',
#    'of',
#    'our',
#    'guy',
#    'luvintheair']),
#  ([['southwestair',
#     'luvin',
#     'me',
#     'some',
#     'flight',
#     'today',
#     'don',
#     'chang',
#     'and',
#     'pleas',
#     'add',
#     'paypal',
#     'as',
#     'payment',
#     'option'],
#    ['southwestair',
#     'make',
#     'fli',
#     'for',
#     'uno_basebal',
#     'fun',
#     'flight',
#     'crew',
#     'just',
#     'led',
#     'the',
#     'plane',
#     'in',
#     'sing',
#     'happi',
#     'birthday',
#     'to',
#     'one',
#     'of',
#     'our',
#     'guy',
#     'luvintheair'],
#    ['thank', 'southwestair', 'heartlanta']],
#   ['southwestair',
#    'just',
#    'receiv',
#    'your',
#    'birthday',
#    'card',
#    'it',
#    'wa',
#    'amaz',
#    'and',
#    'made',
#    'me',
#    'smile',
#    'with',
#    'joy',
#    'nice',
#    'video',
#    'thank']),
#  ([['southwestair',
#     'make',
#     'fli',
#     'for',
#     'uno_basebal',
#     'fun',
#     'flight',
#     'crew',
#     'just',
#     'led',
#     'the',
#     'plane',
#     'in',
#     'sing',
#     'happi',
#     'birthday',
#     'to',
#     'one',
#     'of',
#     'our',
#     'guy',
#     'luvintheair'],
#    ['southwestair',
#     'just',
#     'receiv',
#     'your',
#     'birthday',
#     'card',
#     'it',
#     'wa',
#     'amaz',
#     'and',
#     'made',
#     'me',
#     'smile',
#     'with',
#     'joy',
#     'nice',
#     'video',
#     'thank'],
#    ['southwestair',
#     'thank',
#     'for',
#     'the',
#     'day',
#     'concert',
#     'watch',
#     'them',
#     'all',
#     'and',
#     'notic',
#     'the',
#     'fist',
#     'bump',
#     'high',
#     'five',
#     'at',
#     'the',
#     'end',
#     'of',
#     'the',
#     'rock',
#     'version']],
#   ['thank', 'southwestair', 'heartlanta']),
#  ([['southwestair',
#     'just',
#     'receiv',
#     'your',
#     'birthday',
#     'card',
#     'it',
#     'wa',
#     'amaz',
#     'and',
#     'made',
#     'me',
#     'smile',
#     'with',
#     'joy',
#     'nice',
#     'video',
#     'thank'],
#    ['thank', 'southwestair', 'heartlanta'],
#    ['southwestair',
#     'my',
#     'boyfriend',
#     'and',
#     'have',
#     'love',
#     'imaginedragon',
#     'sinc',
#     'amp',
#     'it',
#     'would',
#     'be',
#     'so',
#     'awesom',
#     'to',
#     'go',
#     'to',
#     'vega',
#     'event',
#     'ani',
#     'way',
#     'you',
#     'can',
#     'help']],
#   ['southwestair',
#    'thank',
#    'for',
#    'the',
#    'day',
#    'concert',
#    'watch',
#    'them',
#    'all',
#    'and',
#    'notic',
#    'the',
#    'fist',
#    'bump',
#    'high',
#    'five',
#    'at',
#    'the',
#    'end',
#    'of',
#    'the',
#    'rock',
#    'version']),
#  ([['thank', 'southwestair', 'heartlanta'],
#    ['southwestair',
#     'thank',
#     'for',
#     'the',
#     'day',
#     'concert',
#     'watch',
#     'them',
#     'all',
#     'and',
#     'notic',
#     'the',
#     'fist',
#     'bump',
#     'high',
#     'five',
#     'at',
#     'the',
#     'end',
#     'of',
#     'the',
#     'rock',
#     'version'],
#    ['southwestair', 'thank', 'you', 'great', 'tool']],
#   ['southwestair',
#    'my',
#    'boyfriend',
#    'and',
#    'have',
#    'love',
#    'imaginedragon',
#    'sinc',
#    'amp',
#    'it',
#    'would',
#    'be',
#    'so',
#    'awesom',
#    'to',
#    'go',
#    'to',
#    'vega',
#    'event',
#    'ani',
#    'way',
#    'you',
#    'can',
#    'help']),
#  ...]

# %%
# Skip-gram model (sg = 1)
size = 400
window = 3
min_count = 1
workers = 3
sg = 1

model_file = 'word2vec.model'
start_time = time.time()
stemmed_tokens = small_df['stemmed_tokens']

w2v_model = models.CBOW(stemmed_tokens, vector_size=size, min_count = min_count, workers = workers, window = window, sg = sg)
print("Time taken to train word2vec model: " + str(time.time() - start_time))
w2v_model.save(model_file)

# %%
w2v_model.wv.key_to_index.keys()
